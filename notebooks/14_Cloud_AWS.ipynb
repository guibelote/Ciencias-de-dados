# %% [markdown]
# # Computação em Nuvem (AWS)
#
# Objetivos: guia prático para deploy de um Streamlit em S3/Elastic Beanstalk (simulado).

# %%
# Guia: comandos e passos para deploy (não executável aqui)
print('Este notebook traz instruções para subir um app Streamlit na nuvem e exemplos de infraestrutura.')
