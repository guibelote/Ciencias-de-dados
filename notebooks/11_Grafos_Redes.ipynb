# %% [markdown]
# # Grafos e Redes Sociais
#
# Objetivos: criar e analisar um grafo com networkx.

# %%
import networkx as nx
G = nx.Graph()
G.add_edges_from([('A','B'),('A','C'),('B','C'),('C','D')])
print("Nós:", G.nodes())
print("Grau de C:", G.degree('C'))
# Desenho (matplotlib necessário)
try:
    import matplotlib.pyplot as plt
    nx.draw(G, with_labels=True)
    plt.show()
except Exception as e:
    print('matplotlib não disponível:', e)
